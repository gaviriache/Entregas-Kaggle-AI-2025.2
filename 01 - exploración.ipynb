# %% [markdown]
# <a href="https://colab.research.google.com/github/gaviriache/Entregas-Kaggle-AI-2025.2/blob/main/01%20-%20exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***01.01 - PROYECTO KAGGLE***

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/ai4eng.v1/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# <meta name="google-signin-client_id"
#       content="461673936472-kdjosv61up3ac1ajeuq6qqu72upilmls.apps.googleusercontent.com"/>
# <script src="https://apis.google.com/js/client:platform.js?onload=google_button_start"></script>
# replicating local resources
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
# Instalación del package de Kaggle

# !pip install kaggle --quiet

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '.'

# %%
# Verificación del archivo .json en el folder Content del Workspace
# !pwd
# !ls -l
# Out:
# /content
# total 20
# -rw-r--r-- 1 root root 2099 Oct  6 03:11 init.py
# -rw-r--r-- 1 root root   73 Oct  6 03:07 kaggle.json
# drwxr-xr-x 5 root root 4096 Oct  6 03:11 local
# drwxr-xr-x 2 root root 4096 Oct  6 03:11 __pycache__
# drwxr-xr-x 1 root root 4096 Oct  2 13:36 sample_data

# %% [markdown]
# ## Pasos Preliminares: Obtener el Token
#
#
# 1.   [https://www.kaggle.com/
#  → Account → API → Create New API Token].
# 2.   Esto descargará un archivo llamado kaggle.json con las credenciales de acceso.
# 3. Cargar el archivo kaggle.json al entorno de ejecución en /content/kaggle.json.
#
#
#
# ###  Definiciones
#
# *   Ubicación del token de conexión -> os.environ['KAGGLE_CONFIG_DIR'] = '.'
# *   Configuración de permisos -> !chmod 600
# *   API para descargar Datasets.
#
#
#
#
# Colab - API Kaggle **texto en negrita**

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'
# !chmod 600 ./kaggle.json
# !kaggle competitions download -c udea-ai-4-eng-20252-pruebas-saber-pro-colombia
# Out:
# udea-ai-4-eng-20252-pruebas-saber-pro-colombia.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ## Descompresión del package de datasets - .ZIP

# %%
# !unzip udea*.zip > /dev/null

# %%
# !wc *.csv
# Out:
#    296787    296787   4716673 submission_example.csv
#    296787   4565553  59185238 test.csv
#    692501  10666231 143732437 train.csv
#   1286075  15528571 207634348 total

# %% [markdown]
# ### Cargar Dataset " train.csv " a Dataframe de Pandas PY.

# %%
import pandas as pd
import numpy as np

df_train = pd.read_csv('train.csv')
print('\n----------------------------------------------------------\n')
print("Tipos de datos por columna :: \n", df_train.dtypes)
print('\n----------------------------------------------------------\n')
print("Estadisticas del Dataset :: \n", df_train.describe())
print('\n----------------------------------------------------------\n')
print ("Dimensiones de Matriz M x N Dataframe: TRAIN ::  \n", df_train.shape, '\n----------------------------------------------------------')
df_train.head()
# Out:
# ----------------------------------------------------------
#
# Tipos de datos por columna ::
#  ID                               int64
# PERIODO_ACADEMICO                int64
# E_PRGM_ACADEMICO                object
# E_PRGM_DEPARTAMENTO             object
# E_VALORMATRICULAUNIVERSIDAD     object
# E_HORASSEMANATRABAJA            object
# F_ESTRATOVIVIENDA               object
# F_TIENEINTERNET                 object
# F_EDUCACIONPADRE                object
# F_TIENELAVADORA                 object
# F_TIENEAUTOMOVIL                object
# E_PRIVADO_LIBERTAD              object
# E_PAGOMATRICULAPROPIO           object
# F_TIENECOMPUTADOR               object
# F_TIENEINTERNET.1               object
# F_EDUCACIONMADRE                object
# RENDIMIENTO_GLOBAL              object
# INDICADOR_1                    float64
# INDICADOR_2                    float64
# INDICADOR_3                    float64
# INDICADOR_4                    float64
# dtype: object
#
# ...

# %% [markdown]
# #  Proporciones por programa académico :::

# %%
programas, conteos = np.unique(df_train['E_PRGM_ACADEMICO'], return_counts=True)
proporciones = conteos / conteos.sum()
for p, prop in zip(programas, proporciones):
    print(f"{p}: {prop:.2%}")
# Out:
# 3°  CICLO PROFESIONAL NEGOCIOS INTERNACIONALES: 0.01%
# ACTIVIDAD FISICA Y DEPORTE: 0.02%
# ACUICULTURA: 0.01%
# ADMINISTRACION: 0.02%
# ADMINISTRACION  FINANCIERA: 0.01%
# ADMINISTRACION & SERVICIO: 0.00%
# ADMINISTRACION AERONAUTICA: 0.01%
# ADMINISTRACION AGROPECUARIA: 0.02%
# ADMINISTRACION AMBIENTAL: 0.08%
# ADMINISTRACION AMBIENTAL Y DE LOS RECURSOS NATURALES: 0.04%
# ADMINISTRACION BANCARIA Y FINANCIERA: 0.02%
# ADMINISTRACION COMERCIAL: 0.01%
# ADMINISTRACION COMERCIAL Y DE MERCADEO: 0.07%
# ADMINISTRACION DE COMERCIO EXTERIOR: 0.00%
# ADMINISTRACION DE EMPRESAS: 7.49%
# ADMINISTRACION DE EMPRESAS  Y  GESTION AMBIENTAL: 0.02%
# ADMINISTRACION DE EMPRESAS AGROINDUSTRIALES: 0.00%
# ADMINISTRACION DE EMPRESAS AGROPECUARIAS: 0.09%
# ADMINISTRACION DE EMPRESAS COMERCIALES: 0.07%
# ADMINISTRACION DE EMPRESAS EN TELECOMUNICACIONES: 0.00%
# ADMINISTRACION DE EMPRESAS TURISTICA: 0.00%
# ADMINISTRACION DE EMPRESAS TURISTICAS: 0.03%
# ...
